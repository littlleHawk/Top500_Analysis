# %% [markdown]
# ## Top500 et Green500: dashboard interactif

# %%
# Imports
import project_lib as mod

# Import local classes
import widgets as w
import widget_functions as wf

import plotly.io as pio
pio.renderers.default = 'notebook'


mod.VERBOSE_VAL = False  # Set to True for verbose output

# %%
# Eviter calculaer plusier fois le meme system
# GPU Fuzzy check -> Frontier
#wrap Dash
dash = mod.VBox([w.tau_slider, 
                w.alpha_slider,
                w.lifespan_estimation, 
                w.carbon_choice, 
                w.country_choice,
                w.listing_choice,
                w.sector_choice, 
                w.infos1, w.infos2, 
                w.infos3, w.infos4,
                wf.outTotals])

#Show Dash
display(dash)
